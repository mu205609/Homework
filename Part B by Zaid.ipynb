# %% [markdown]
# # CI280 - Final Project - Part B
# #
# # Data Preparation, Sort, Groupby and Plot( 100 pts)
#
# ## Name: ZAID MUKARDAMWALA
# ### Student Id : MU20609

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 8))

# %%
df = pd.read_csv('data//owid-covid-data.csv')

# %%
# limiting the display rows
pd.set_option('display.max_rows', 5)
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 61563      ZWE    Africa     Zimbabwe  2020-12-06      10718.0      101.0
# 61564      ZWE    Africa     Zimbabwe  2020-12-07      10839.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 61563               128.0         291.0         0.0                2.286  ...
# 61564               127.0         294.0         3.0                2.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 61563        1899.775             21.4                307.846
# 61564        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 61563                 1.82             1.6          30.7
# 61564                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 61563                  36.791                         1.7            61.49
# 61564                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 61563                    0.535
# 61564                    0.535
#
# [61565 rows x 50 columns]

# %%
df = df[ (df['location'] != 'World') ]
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-01-23          NaN        0.0
# 1          AFG      Asia  Afghanistan  2020-01-24          NaN        0.0
# ...        ...       ...          ...         ...          ...        ...
# 61563      ZWE    Africa     Zimbabwe  2020-12-06      10718.0      101.0
# 61564      ZWE    Africa     Zimbabwe  2020-12-07      10839.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 61563               128.0         291.0         0.0                2.286  ...
# 61564               127.0         294.0         3.0                2.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 61563        1899.775             21.4                307.846
# 61564        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 61563                 1.82             1.6          30.7
# 61564                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 61563                  36.791                         1.7            61.49
# 61564                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# ...                        ...
# 61563                    0.535
# 61564                    0.535
#
# [61244 rows x 50 columns]

# %%
# Show number of records 
import random
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')
print("Number of Records:" ,len(df))
# Out:
# Zaid , id:mu20609  7531
# ------------------------------
# Number of Records: 61244

# %% [markdown]
# ## C) Handing Missing Data and Ploting (20 pts)
#
# ### use isnull() vs. notnull()
# ### use dropna
# ### use replacena

# %%
# show last five rows
df.tail()
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 61560      ZWE    Africa  Zimbabwe  2020-12-03      10424.0      295.0
# 61561      ZWE    Africa  Zimbabwe  2020-12-04      10547.0      123.0
# 61562      ZWE    Africa  Zimbabwe  2020-12-05      10617.0       70.0
# 61563      ZWE    Africa  Zimbabwe  2020-12-06      10718.0      101.0
# 61564      ZWE    Africa  Zimbabwe  2020-12-07      10839.0      121.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 61560             114.429         280.0         3.0                0.857  ...
# 61561             119.000         281.0         1.0                0.857  ...
# 61562             113.571         291.0        10.0                2.286  ...
# 61563             128.000         291.0         0.0                2.286  ...
# 61564             127.000         294.0         3.0                2.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 61560        1899.775             21.4                307.846
# 61561        1899.775             21.4                307.846
# 61562        1899.775             21.4                307.846
# 61563        1899.775             21.4                307.846
# 61564        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 61560                 1.82             1.6          30.7
# 61561                 1.82             1.6          30.7
# 61562                 1.82             1.6          30.7
# 61563                 1.82             1.6          30.7
# 61564                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 61560                  36.791                         1.7            61.49
# 61561                  36.791                         1.7            61.49
# 61562                  36.791                         1.7            61.49
# 61563                  36.791                         1.7            61.49
# 61564                  36.791                         1.7            61.49
#
#        human_development_index
# 61560                    0.535
# 61561                    0.535
# 61562                    0.535
# 61563                    0.535
# 61564                    0.535
#
# [5 rows x 50 columns]

# %%
# show the number of rows and columns of datafram 
df.shape
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# 1) Show the number records of miss data for continent ( 2 pts)
#    Show the the last five those records 

print('The number records missing data for continent')
print(len(df[df.continent.isnull()]))
df[df.continent.isnull()].tail()
# Out:
# Zaid , id:mu20609  9973
# ------------------------------
# The number records missing data for continent
# 320
#       iso_code continent       location        date  total_cases  new_cases  \
# 25027      NaN       NaN  International  2020-12-03        721.0        0.0
# 25028      NaN       NaN  International  2020-12-04        721.0        0.0
# 25029      NaN       NaN  International  2020-12-05        721.0        0.0
# 25030      NaN       NaN  International  2020-12-06        721.0        0.0
# 25031      NaN       NaN  International  2020-12-07        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 25027                 0.0          15.0         0.0                  0.0  ...
# 25028                 0.0          15.0         0.0                  0.0  ...
# 25029                 0.0          15.0         0.0                  0.0  ...
# 25030                 0.0          15.0         0.0                  0.0  ...
# 25031                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 25027             NaN              NaN                    NaN
# 25028             NaN              NaN                    NaN
# 25029             NaN              NaN                    NaN
# 25030             NaN              NaN                    NaN
# 25031             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 25027                  NaN             NaN           NaN
# 25028                  NaN             NaN           NaN
# 25029                  NaN             NaN           NaN
# 25030                  NaN             NaN           NaN
# 25031                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 25027                     NaN                         NaN              NaN
# 25028                     NaN                         NaN              NaN
# 25029                     NaN                         NaN              NaN
# 25030                     NaN                         NaN              NaN
# 25031                     NaN                         NaN              NaN
#
#        human_development_index
# 25027                      NaN
# 25028                      NaN
# 25029                      NaN
# 25030                      NaN
# 25031                      NaN
#
# [5 rows x 50 columns]

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')


# 2-3) Show the number records of miss data for continent and iso_code (2 pts)
#    Show the the last five those records ( 2 pts)

print('The number records missing data for continent and iso_code')
print(len(df[df.continent.isnull() & df.iso_code.isnull()]))
df[df.continent.isnull() & df.iso_code.isnull()].tail()
# Out:
# Zaid , id:mu20609  8193
# ------------------------------
# The number records missing data for continent and iso_code
# 320
#       iso_code continent       location        date  total_cases  new_cases  \
# 25027      NaN       NaN  International  2020-12-03        721.0        0.0
# 25028      NaN       NaN  International  2020-12-04        721.0        0.0
# 25029      NaN       NaN  International  2020-12-05        721.0        0.0
# 25030      NaN       NaN  International  2020-12-06        721.0        0.0
# 25031      NaN       NaN  International  2020-12-07        721.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 25027                 0.0          15.0         0.0                  0.0  ...
# 25028                 0.0          15.0         0.0                  0.0  ...
# 25029                 0.0          15.0         0.0                  0.0  ...
# 25030                 0.0          15.0         0.0                  0.0  ...
# 25031                 0.0          15.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 25027             NaN              NaN                    NaN
# 25028             NaN              NaN                    NaN
# 25029             NaN              NaN                    NaN
# 25030             NaN              NaN                    NaN
# 25031             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 25027                  NaN             NaN           NaN
# 25028                  NaN             NaN           NaN
# 25029                  NaN             NaN           NaN
# 25030                  NaN             NaN           NaN
# 25031                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 25027                     NaN                         NaN              NaN
# 25028                     NaN                         NaN              NaN
# 25029                     NaN                         NaN              NaN
# 25030                     NaN                         NaN              NaN
# 25031                     NaN                         NaN              NaN
#
#        human_development_index
# 25027                      NaN
# 25028                      NaN
# 25029                      NaN
# 25030                      NaN
# 25031                      NaN
#
# [5 rows x 50 columns]

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')



# 4-5) For the records for Bazil, which columns has missing data (4 pts)
res = df[df['location']=='Spain']
res

col_names = res.columns
col_names

print('The following columns are missing data for Spain')

print('Column name \t\t\t\tMissing Data')
print('------------------------------------------------')
for name in col_names:
    num = len(res[res[name].isnull()])
    if num > 0:
        print('{0: <40}'.format(name), num)
# Out:
# Zaid , id:mu20609  9592
# ------------------------------
# The following columns are missing data for Spain
# Column name 				Missing Data
# ------------------------------------------------
# total_cases                              9
# new_cases_smoothed                       5
# total_deaths                             40
# new_deaths_smoothed                      5
# total_cases_per_million                  9
# new_cases_smoothed_per_million           5
# total_deaths_per_million                 40
# new_deaths_smoothed_per_million          5
# reproduction_rate                        50
# icu_patients                             249
# icu_patients_per_million                 249
# hosp_patients                            249
# hosp_patients_per_million                249
# weekly_icu_admissions                    276
# weekly_icu_admissions_per_million        276
# weekly_hosp_admissions                   276
# weekly_hosp_admissions_per_million       276
# total_tests                              287
# new_tests                                320
# total_tests_per_thousand                 287
# new_tests_per_thousand                   320
# new_tests_smoothed                       99
# new_tests_smoothed_per_thousand          99
# positive_rate                            99
# tests_per_case                           99
# tests_units                              92
# handwashing_facilities                   320

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')


#df.columns

df.shape
# .dropna() vs. . dropna(how='all')

# 6) Show the result after droping rows which have at least one NaN data in the dataset ()  (2 pts)
cleaned = df.dropna()

print('After using .dropn(), total records: ')
print(len(cleaned))
# Out:
# Zaid , id:mu20609  5387
# ------------------------------
# After using .dropn(), total records:
# 0

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# 7) Show the result after after droping rows which all data is NaN in the dataset ()  (2 pts)
res = df[df['location']=='Spain']
res
cleaned = res.dropna(how='all')

print("After using .dropna(how='all'), total records:")
print(len(cleaned))
# Out:
# Zaid , id:mu20609  6244
# ------------------------------
# After using .dropna(how='all'), total records:
# 320

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

print(df.shape)
print('Original row number:', len(df))

# 8) Show the result after dropping the rows which continent or iso data is missing in the dataset
#    How many rows are dropped. (2 pts)

cleaned_data = df[df.continent.notnull() & df.iso_code.notnull()]
bad_data = df[df.continent.isnull() | df.iso_code.isnull()]
print('After droping all missing data of continent or iso in the dataset')
print('New dataset included record number:', len(cleaned_data))
print('The number of rows droped:', len(bad_data))
# Out:
# Zaid , id:mu20609  2888
# ------------------------------
# (61244, 50)
# Original row number: 61244
# After droping all missing data of continent or iso in the dataset
# New dataset included record number: 60924
# The number of rows droped: 320

# %%
res = df[df['location']=='Spain']
res[['location','handwashing_facilities']]
# Out:
#       location  handwashing_facilities
# 50977    Spain                     NaN
# 50978    Spain                     NaN
# ...        ...                     ...
# 51295    Spain                     NaN
# 51296    Spain                     NaN
#
# [320 rows x 2 columns]

# %%
# 9) Show Spain's handwashing_facilities information
#    Show the average of handwashing_facilities of worldwide level

import random
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

#print(df['handwashing_facilities'].describe())


print("Handwashing_facilities values are missing in Spain")
res = df[df['location']=='Spain']
print(len(res))
data = res[res['handwashing_facilities'].isnull()] [['location','date','handwashing_facilities']]
print(data)

avg = df['handwashing_facilities'].mean()
print('The average of handwashing facilities worldwide:', format(avg, '.0f'))
# Out:
# Zaid , id:mu20609  765
# ------------------------------
# Handwashing_facilities values are missing in Spain
# 320
#       location        date  handwashing_facilities
# 50977    Spain  2020-01-23                     NaN
# 50978    Spain  2020-01-24                     NaN
# ...        ...         ...                     ...
# 51295    Spain  2020-12-06                     NaN
# 51296    Spain  2020-12-07                     NaN
#
# [320 rows x 3 columns]
# The average of handwashing facilities worldwide: 50

# %%
# 10) Replace handwashing_facilities in Saudi arabia as the average of worldwide level (2 pts)


res = df[df['location']=='Saudi arabia']
avg = df['handwashing_facilities'].mean()
avg = math.floor(avg)

print('Now handwashing facilities values are replaced by the average of worldwide level')
data

res['handwashing_facilities'].fillna(avg, inplace=True)
res[['location', 'date','handwashing_facilities']]
# Out:
# Now handwashing facilities values are replaced by the average of worldwide level
# Empty DataFrame
# Columns: [location, date, handwashing_facilities]
# Index: []

# %% [markdown]
# # D) Sorting, Grouping and Plotting (30 points)
#
# ## df.sort_values(by=['a','b'], ascending = True)
# ## df.sort_index()
# ## df.groupby( )

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')
import matplotlib.pyplot as plt

# 1)  (3 pts) Find the top 10 countries which have the most covid cases

# Group all cases by location , become series
cases = df.groupby(df.location).new_cases.sum()
cases = cases.sort_values(ascending = False)
cases

res = cases.head(10)
countries = res.index

print('Ten countries which have the most covid cases:')
print('Country              Covid cases')
print('---------------------------------------------')
for country in countries:
    print('{0: <20}'.format(country), '\t', format(res[country],'.0f'))
# Out:
# Zaid , id:mu20609  5940
# ------------------------------
# Ten countries which have the most covid cases:
# Country              Covid cases
# ---------------------------------------------
# United States        	 14949298
# India                	 9703770
# Brazil               	 6623911
# Russia               	 2466961
# France               	 2349059
# Italy                	 1742557
# United Kingdom       	 1742525
# Spain                	 1702328
# Argentina            	 1466309
# Colombia             	 1377100

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')


# 2) Use bar chart to show the top 10 countries which have the most covid cases. (3 pts)
res = cases.head(10)
res

print(res.index)
print(res.values)

res.plot(kind='bar', title='10 countries which have the most covid cases')
# Out:
# Zaid , id:mu20609  4368
# ------------------------------
# Index(['United States', 'India', 'Brazil', 'Russia', 'France', 'Italy',
#        'United Kingdom', 'Spain', 'Argentina', 'Colombia'],
#       dtype='object', name='location')
# [14949298.  9703770.  6623911.  2466961.  2349059.  1742557.  1742525.
#   1702328.  1466309.  1377100.]

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# (3  pts)

# 3) Show worldwide, which ten day has the most new cases? 

#    Use line chart to show the top 10 days which have the most new covid cases 
cases = df.groupby(df.date).new_cases.sum()
cases = cases.sort_values(ascending = False)

res = cases.head(10)
res = res.sort_index()

days = res.index

print ('10 days which have the most Covid Cases')
print ('Date                     Covid Cases')
print ('---------------------------------------------------')

for day in days:
    print(day, '\t', format (res[day], '.0f'))

    
# Draw bar chart
plt.title('Top 10 days which have the most new Covid Cases')
plt.xlabel('Date')
plt.ylabel('Numbers')

plt.plot(res.index,res.values, color ='b')

res.plot (kind='line', rot = 45, linestyle = 'dashed' , marker = 'o')
# Out:
# Zaid , id:mu20609  7931
# ------------------------------
# 10 days which have the most Covid Cases
# Date                     Covid Cases
# ---------------------------------------------------
# 2020-11-06 	 642314
# 2020-11-11 	 645408
# 2020-11-12 	 647336
# 2020-11-13 	 649123
# 2020-11-19 	 650767
# 2020-11-20 	 665858
# 2020-11-27 	 672318
# 2020-12-02 	 646568
# 2020-12-03 	 690523
# 2020-12-04 	 678316

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# (3  pts)

# 4) On 2020-11-30, which ten countries has the most new cases? 

#    Use bar chart to show the top 10 location which have the most new covid cases 
res = df[df.date=='2020-11-10']

cases = res.sort_values(by='new_cases', ascending = False)

res = cases.head(10)[['location','new_cases']]
res = res.sort_index()

print("On 2020-11-10")
print("10 countries which have the most covid cases on 2020-11-10")
print("Country               Covid cases")
print('----------------------------------------------------')


for i in res.index:
    country = res['location'][i]
    new_cases = res['new_cases'][i]
    print('{0: <20}'.format(country), '\t', format(new_cases, '.0f'))

# Draw bar chart
plt.title("10 countries which have the most covid cases on 2020-11-10")
plt.xlabel("Date")
plt.ylabel("Numbers")

plt.bar(res['location'],res['new_cases'], color='b')
# Out:
# Zaid , id:mu20609  9086
# ------------------------------
# On 2020-11-10
# 10 countries which have the most covid cases on 2020-11-10
# Country               Covid cases
# ----------------------------------------------------
# Brazil               	 23973
# France               	 22471
# Germany              	 26547
# India                	 44281
# Italy                	 35090
# Poland               	 25454
# Russia               	 20765
# Sweden               	 15779
# United Kingdom       	 20451
# United States        	 137694
# <BarContainer object of 10 artists>

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# (3  pts)


#  5)  Show last seven days, the new cases in Brazil/US/India/Russia (Chose one country),
#      Plot a line chart


cases = df[df.location=='Saudi arabia'].sort_values(by='date', ascending=True)
cases
res = cases[['date','new_cases']].tail(7)

print('\nIn the past seven days the new cases in Saudi arabia')
print('Date             Covid cases')
print('------------------------------------------------')

dates = res['date']
for i in res.index:
    print(res['date'][i], '\t', format(res['new_cases'][i], '.0f'))

plt.title('New covid cases in past ten days in Saudi arabia')
plt.xlabel('Date')
plt.ylabel('Numbers')

plt.plot(res['date'],res['new_cases'],color='b')
# Out:
# Zaid , id:mu20609  3750
# ------------------------------
#
# In the past seven days the new cases in Saudi arabia
# Date             Covid cases
# ------------------------------------------------

# %%
number = random.randint(0,10000)
print("Zaid , id: mu20609 ", number )
print('------------------------------')


# 6-7) Group by contient, show total of new covid cases for each contient and sorted by total number
#    Plot the result by pie chart (3 pts)

df
res = df.groupby(df.continent).new_cases.sum().sort_values(ascending=False)

print('Total covid new cases by continent')
print('----------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind='pie', title='Covid new caases of percentages by continent', autopct='%1.1f%%')
# Out:
# Zaid , id: mu20609  577
# ------------------------------
# Total covid new cases by continent
# ----------------------------------
# Europe               	 18707444
# Asia                 	 17649953
# North America        	 17368527
# South America        	 11559429
# Africa               	 2273763
# Oceania              	 30811

# %%
res
# Out:
#       location    population
# 11493    China  1.439324e+09
# 24364    India  1.380004e+09
# ...        ...           ...
# 44547   Russia  1.459345e+08
# 35587   Mexico  1.289328e+08
#
# [10 rows x 2 columns]

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# 8) Show the top 10 countries which have the most population  (3 pts)
df

res = df[df.date=='2020-11-10'][['location', 'population']].sort_values(by = 'population', ascending = False)
res = res.head(10)
res.index

print('Top 10 countries which have the most POPULATION')
for i in res.index:
    print('{0: <20}'.format(res['location'][i]), format(res['population'][i], '.0f'))

res2 = res.set_index('location')
# Out:
# Zaid , id:mu20609  9456
# ------------------------------
# Top 10 countries which have the most POPULATION
# China                1439323774
# India                1380004385
# United States        331002647
# Indonesia            273523621
# Pakistan             220892331
# Brazil               212559409
# Nigeria              206139587
# Bangladesh           164689383
# Russia               145934460
# Mexico               128932753

# %%
number = random.randint(0,10000)
print("Zaid , id:mu20609 ", number )
print('------------------------------')

# 9-10) Show the world poplation
#      Show the  population by each continent and show it as pie chart (6 pts)
data = df[df.date=='2020-11-10']
pop_sum = data['population'].sum()
print('The world population', pop_sum)

data = df[df.date=='2020-11-10'][['continent', 'location', 'date', 'population']]

res = df.groupby([df.continent]).population.sum().sort_values(ascending = False)

print('Population by continent')
print('------------------------------')
names = res.index
for name in names:
    print('{0: <20}'.format(name), '\t', format(res[name], '.0f'))

res.plot(kind='pie', title='Covid new cases of percentages by continent', autopct='%1.1f%%')
# Out:
# Zaid , id:mu20609  6242
# ------------------------------
# The world population 7747023855.0
# Population by continent
# ------------------------------
# Asia                 	 1475658691513
# Africa               	 428615654720
# Europe               	 239414559040
# North America        	 191219849613
# South America        	 137746434240
# Oceania              	 13253509440
